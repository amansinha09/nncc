# %%
import pandas as pd
import numpy as np

import time, os

# %%
with open('/home/amansinha/cmed/data/trainingdata_v3/trainingdata_v3/dev/130-02.txt', 'r') as fp:
    doc = fp.read()

# %%
doc[620:628]
# Out:
# 'levaquin'

# %%
for i in range(len(doc)):
    print(i, doc[i])
# Out:
# 0
#
# 1
#
# 2
#
# 3 R
# 4 e
# 5 c
# 6 o
# 7 r
# 8 d
# 9
# 10 d
# 11 a
# 12 t
# 13 e
# 14 :
# 15
# 16 2
# 17 0
# 18 8
# 19 4
# 20 -
# 21 1
# 22 2
# 23 -
# 24 2
# 25 7
# 26
#
# 27
#
# 28
# 29
#
# 30
#
# 31
#
# 32
#
# 33 J
# 34 A
# 35 R
# 36
# 37 N
# 38 i
# 39 g
# 40 h
# 41 t
# 42 -
# 43 f
# 44 l
# 45 o
# 46 a
# 47 t
# 48
# 49 A
# 50 d
# 51 m
# 52 i
# 53 s
# 54 s
# 55 i
# 56 o
# 57 n
# 58
# 59 N
# 60 o
# 61 t
# 62 e
# 63
#
# 64
#
# 65 I
# 66 n
# 67 t
# 68 e
# 69 r
# 70 n
# 71 a
# 72 l
# 73
# 74 M
# 75 e
# 76 d
# 77 i
# 78 c
# 79 i
# 80 n
# 81 e
# 82
#
# 83
#
# 84
#
# 85
#
# 86 P
# 87 a
# 88 t
# 89 i
# 90 e
# 91 n
# 92 t
# 93 :
# 94
# 95
# 96
# 97
# 98 M
# 99 a
# 100 e
# 101
# 102 P
# 103 a
# 104 u
# 105 l
# 106
# 107
#
# 108
#
# 109 M
# 110 R
# 111 N
# 112 :
# 113
# 114
# 115
# 116
# 117 1
# 118 0
# 119 0
# 120 5
# 121 7
# 122 0
# 123 8
# 124
#
# 125
#
# 126 D
# 127 a
# 128 t
# 129 e
# 130
# 131 o
# 132 f
# 133
# 134 a
# 135 d
# 136 m
# 137 i
# 138 s
# 139 s
# 140 i
# 141 o
# 142 n
# ...
